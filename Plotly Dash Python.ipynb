# %%
# !pip install jupyter-dash
from jupyter_dash import JupyterDash
# Out:
# Requirement already satisfied: jupyter-dash in c:\users\santo\anaconda3\lib\site-packages (0.3.1)
# Requirement already satisfied: flask in c:\users\santo\anaconda3\lib\site-packages (from jupyter-dash) (1.0.2)
# Requirement already satisfied: ipython in c:\users\santo\anaconda3\lib\site-packages (from jupyter-dash) (6.4.0)
# Requirement already satisfied: ansi2html in c:\users\santo\anaconda3\lib\site-packages (from jupyter-dash) (1.5.2)
# Requirement already satisfied: requests in c:\users\santo\anaconda3\lib\site-packages (from jupyter-dash) (2.18.4)
# Requirement already satisfied: retrying in c:\users\santo\anaconda3\lib\site-packages (from jupyter-dash) (1.3.3)
# Requirement already satisfied: dash in c:\users\santo\anaconda3\lib\site-packages (from jupyter-dash) (1.16.3)
# Requirement already satisfied: ipykernel in c:\users\santo\anaconda3\lib\site-packages (from jupyter-dash) (4.8.2)
# Requirement already satisfied: click>=5.1 in c:\users\santo\anaconda3\lib\site-packages (from flask->jupyter-dash) (6.7)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\santo\anaconda3\lib\site-packages (from flask->jupyter-dash) (0.24)
# Requirement already satisfied: Werkzeug>=0.14 in c:\users\santo\anaconda3\lib\site-packages (from flask->jupyter-dash) (0.14.1)
# Requirement already satisfied: Jinja2>=2.10 in c:\users\santo\anaconda3\lib\site-packages (from flask->jupyter-dash) (2.10)
# Requirement already satisfied: jedi>=0.10 in c:\users\santo\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.12.0)
# Requirement already satisfied: backcall in c:\users\santo\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.1.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\santo\anaconda3\lib\site-packages (from ipython->jupyter-dash) (4.3.2)
# Requirement already satisfied: simplegeneric>0.8 in c:\users\santo\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.8.1)
# Requirement already satisfied: pickleshare in c:\users\santo\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.7.4)
# Requirement already satisfied: setuptools>=18.5 in c:\users\santo\anaconda3\lib\site-packages (from ipython->jupyter-dash) (39.1.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.15 in c:\users\santo\anaconda3\lib\site-packages (from ipython->jupyter-dash) (1.0.15)
# Requirement already satisfied: pygments in c:\users\santo\anaconda3\lib\site-packages (from ipython->jupyter-dash) (2.2.0)
# Requirement already satisfied: decorator in c:\users\santo\anaconda3\lib\site-packages (from ipython->jupyter-dash) (4.3.0)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\santo\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.3.9)
# Requirement already satisfied: six in c:\users\santo\anaconda3\lib\site-packages (from ansi2html->jupyter-dash) (1.11.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\santo\anaconda3\lib\site-packages (from requests->jupyter-dash) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\santo\anaconda3\lib\site-packages (from requests->jupyter-dash) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\santo\anaconda3\lib\site-packages (from requests->jupyter-dash) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\santo\anaconda3\lib\site-packages (from requests->jupyter-dash) (2018.4.16)
# Requirement already satisfied: future in c:\users\santo\anaconda3\lib\site-packages (from dash->jupyter-dash) (0.18.2)
# Requirement already satisfied: flask-compress in c:\users\santo\anaconda3\lib\site-packages (from dash->jupyter-dash) (1.7.0)
# Requirement already satisfied: dash-renderer==1.8.2 in c:\users\santo\anaconda3\lib\site-packages (from dash->jupyter-dash) (1.8.2)
# Requirement already satisfied: dash-table==4.10.1 in c:\users\santo\anaconda3\lib\site-packages (from dash->jupyter-dash) (4.10.1)
# Requirement already satisfied: dash-html-components==1.1.1 in c:\users\santo\anaconda3\lib\site-packages (from dash->jupyter-dash) (1.1.1)
# Requirement already satisfied: dash-core-components==1.12.1 in c:\users\santo\anaconda3\lib\site-packages (from dash->jupyter-dash) (1.12.1)
# Requirement already satisfied: plotly in c:\users\santo\anaconda3\lib\site-packages (from dash->jupyter-dash) (4.11.0)
# Requirement already satisfied: jupyter_client in c:\users\santo\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (5.2.3)
# Requirement already satisfied: tornado>=4.0 in c:\users\santo\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (5.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\santo\anaconda3\lib\site-packages (from Jinja2>=2.10->flask->jupyter-dash) (1.0)
# Requirement already satisfied: parso>=0.2.0 in c:\users\santo\anaconda3\lib\site-packages (from jedi>=0.10->ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: ipython_genutils in c:\users\santo\anaconda3\lib\site-packages (from traitlets>=4.2->ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\santo\anaconda3\lib\site-packages (from prompt-toolkit<2.0.0,>=1.0.15->ipython->jupyter-dash) (0.1.7)
# Requirement already satisfied: brotli in c:\users\santo\anaconda3\lib\site-packages (from flask-compress->dash->jupyter-dash) (1.0.9)
# Requirement already satisfied: jupyter_core in c:\users\santo\anaconda3\lib\site-packages (from jupyter_client->ipykernel->jupyter-dash) (4.4.0)
# Requirement already satisfied: pyzmq>=13 in c:\users\santo\anaconda3\lib\site-packages (from jupyter_client->ipykernel->jupyter-dash) (17.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\santo\anaconda3\lib\site-packages (from jupyter_client->ipykernel->jupyter-dash) (2.7.3)
# WARNING: You are using pip version 20.2.2; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\users\santo\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd

# %%
df = pd.read_csv('https://plotly.github.io/datasets/country_indicators.csv')
available_indicators = df['Indicator Name'].unique()

# %%
df.head()
# Out:
#   Country Name                                     Indicator Name  Year  \
# 0   Arab World                Agriculture, value added (% of GDP)  1962
# 1   Arab World             CO2 emissions (metric tons per capita)  1962
# 2   Arab World  Domestic credit provided by financial sector (...  1962
# 3   Arab World        Electric power consumption (kWh per capita)  1962
# 4   Arab World       Energy use (kg of oil equivalent per capita)  1962
#
#        Value
# 0        NaN
# 1   0.760996
# 2  18.168690
# 3        NaN
# 4        NaN

# %%
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = JupyterDash(__name__, external_stylesheets=external_stylesheets)

# Create server variable with Flask server object for use with gunicorn
server = app.server

app.layout = html.Div([
    html.Div([

        html.Div([
            dcc.Dropdown(
                id='crossfilter-xaxis-column',
                options=[{'label': i, 'value': i} for i in available_indicators],
                value='Fertility rate, total (births per woman)'
            ),
            dcc.RadioItems(
                id='crossfilter-xaxis-type',
                options=[{'label': i, 'value': i} for i in ['Linear', 'Log']],
                value='Linear',
                labelStyle={'display': 'inline-block'}
            )
        ],
        style={'width': '49%', 'display': 'inline-block'}),

        html.Div([
            dcc.Dropdown(
                id='crossfilter-yaxis-column',
                options=[{'label': i, 'value': i} for i in available_indicators],
                value='Life expectancy at birth, total (years)'
            ),
            dcc.RadioItems(
                id='crossfilter-yaxis-type',
                options=[{'label': i, 'value': i} for i in ['Linear', 'Log']],
                value='Linear',
                labelStyle={'display': 'inline-block'}
            )
        ], style={'width': '49%', 'float': 'right', 'display': 'inline-block'})
    ], style={
        'borderBottom': 'thin lightgrey solid',
        'backgroundColor': 'rgb(250, 250, 250)',
        'padding': '10px 5px'
    }),

    html.Div([
        dcc.Graph(
            id='crossfilter-indicator-scatter',
            hoverData={'points': [{'customdata': 'Japan'}]}
        )
    ], style={'width': '49%', 'display': 'inline-block', 'padding': '0 20'}),
    html.Div([
        dcc.Graph(id='x-time-series'),
        dcc.Graph(id='y-time-series'),
    ], style={'display': 'inline-block', 'width': '49%'}),

    html.Div(dcc.Slider(
        id='crossfilter-year--slider',
        min=df['Year'].min(),
        max=df['Year'].max(),
        value=df['Year'].max(),
        marks={str(year): str(year) for year in df['Year'].unique()},
        step=None
    ), style={'width': '49%', 'padding': '0px 20px 20px 20px'})
])


@app.callback(
    dash.dependencies.Output('crossfilter-indicator-scatter', 'figure'),
    [dash.dependencies.Input('crossfilter-xaxis-column', 'value'),
     dash.dependencies.Input('crossfilter-yaxis-column', 'value'),
     dash.dependencies.Input('crossfilter-xaxis-type', 'value'),
     dash.dependencies.Input('crossfilter-yaxis-type', 'value'),
     dash.dependencies.Input('crossfilter-year--slider', 'value')])
def update_graph(xaxis_column_name, yaxis_column_name,
                 xaxis_type, yaxis_type,
                 year_value):
    dff = df[df['Year'] == year_value]

    return {
        'data': [dict(
            x=dff[dff['Indicator Name'] == xaxis_column_name]['Value'],
            y=dff[dff['Indicator Name'] == yaxis_column_name]['Value'],
            text=dff[dff['Indicator Name'] == yaxis_column_name]['Country Name'],
            customdata=dff[dff['Indicator Name'] == yaxis_column_name]['Country Name'],
            mode='markers',
            marker={
                'size': 25,
                'opacity': 0.7,
                'color': 'orange',
                'line': {'width': 2, 'color': 'purple'}
            }
        )],
        'layout': dict(
            xaxis={
                'title': xaxis_column_name,
                'type': 'linear' if xaxis_type == 'Linear' else 'log'
            },
            yaxis={
                'title': yaxis_column_name,
                'type': 'linear' if yaxis_type == 'Linear' else 'log'
            },
            margin={'l': 40, 'b': 30, 't': 10, 'r': 0},
            height=450,
            hovermode='closest'
        )
    }


def create_time_series(dff, axis_type, title):
    return {
        'data': [dict(
            x=dff['Year'],
            y=dff['Value'],
            mode='lines+markers'
        )],
        'layout': {
            'height': 225,
            'margin': {'l': 20, 'b': 30, 'r': 10, 't': 10},
            'annotations': [{
                'x': 0, 'y': 0.85, 'xanchor': 'left', 'yanchor': 'bottom',
                'xref': 'paper', 'yref': 'paper', 'showarrow': False,
                'align': 'left', 'bgcolor': 'rgba(255, 255, 255, 0.5)',
                'text': title
            }],
            'yaxis': {'type': 'linear' if axis_type == 'Linear' else 'log'},
            'xaxis': {'showgrid': False}
        }
    }


@app.callback(
    dash.dependencies.Output('x-time-series', 'figure'),
    [dash.dependencies.Input('crossfilter-indicator-scatter', 'hoverData'),
     dash.dependencies.Input('crossfilter-xaxis-column', 'value'),
     dash.dependencies.Input('crossfilter-xaxis-type', 'value')])
def update_y_timeseries(hoverData, xaxis_column_name, axis_type):
    country_name = hoverData['points'][0]['customdata']
    dff = df[df['Country Name'] == country_name]
    dff = dff[dff['Indicator Name'] == xaxis_column_name]
    title = '<b>{}</b><br>{}'.format(country_name, xaxis_column_name)
    return create_time_series(dff, axis_type, title)


@app.callback(
    dash.dependencies.Output('y-time-series', 'figure'),
    [dash.dependencies.Input('crossfilter-indicator-scatter', 'hoverData'),
     dash.dependencies.Input('crossfilter-yaxis-column', 'value'),
     dash.dependencies.Input('crossfilter-yaxis-type', 'value')])
def update_x_timeseries(hoverData, yaxis_column_name, axis_type):
    dff = df[df['Country Name'] == hoverData['points'][0]['customdata']]
    dff = dff[dff['Indicator Name'] == yaxis_column_name]
    return create_time_series(dff, axis_type, yaxis_column_name)

app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash app running on http://127.0.0.1:8050/
